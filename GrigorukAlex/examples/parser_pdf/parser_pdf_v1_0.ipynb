# %%
# !sudo apt update
# !sudo apt install xpdf
# !pip install pdfplumber
# !pip install pdf2image
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [47.2 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [632 kB]
# Get:9 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,535 kB]
# ...

# %%
# !git clone https://github.com/terrainternship/Pragmatick_OCR_g.git
# Out:
# Cloning into 'Pragmatick_OCR_g'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 105 (delta 24), reused 47 (delta 19), pack-reused 51
# Receiving objects: 100% (105/105), 74.59 MiB | 33.43 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
from Pragmatick_OCR_g.GrigorukAlex.parser_pdf.bboxes import parse

pdf_path = '/content/Pragmatick_OCR_g/GrigorukAlex/examples/parser_pdf/db/testPDF.pdf'  # пример PDF-файла
parse(pdf_path,
      skip_num_tables=4,    # Кол-во таблиц, которые нужно пропустить на первой странице
      padding=(0.9, 0.65, 1.1, 0.6)   # Отступ сверху и сниху от границ таблицы в % от ширины и высоты страницы
      )
# Out:
# (595, 841)
# Кол-во страниц в PDF:  3  | Файл:  /content/Pragmatick_OCR_g/GrigorukAlex/examples/parser_pdf/db/testPDF.pdf
# Кол-во таблиц на странице  1  :  5  шт
# Кол-во таблиц на странице  2  :  10  шт
# Кол-во таблиц на странице  3  :  0  шт
# ...

# %%
from google.colab.patches import cv2_imshow
from PIL import Image

path_img = '/content/Pragmatick_OCR_g/GrigorukAlex/examples/parser_pdf/db/testPDF/'

img = Image.open(path_img + 'page_1.png')
display(img)
img = Image.open(path_img + 'page_2.png')
display(img)
img = Image.open(path_img + 'page_3.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=827x1170>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=827x1170>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=827x1170>

# %%
import json
with open('/content/Pragmatick_OCR_g/GrigorukAlex/examples/parser_pdf/db/testPDF.json', 'r') as f:
  json_string = json.dumps(json.load(f), default=lambda o: o.__dict__, sort_keys=True, indent=4)
print(json_string)
# Out:
# {
#     "num_pages": 3,
#     "pages": {
#         "1": {
#             "num_tables": 5,
#             "tables": {
#                 "1": {
#                     "bottom": 0.5571557669441142,
#                     "left": 0.07584873949579832,
#                     "right": 0.9103411764705882,
#                     "top": 0.5269244946492272
#                 },
#                 "2": {
#                     "bottom": 0.6198834720570748,
#                     "left": 0.07584873949579832,
#                     "right": 0.9103411764705882,
#                     "top": 0.5896521997621879
#                 },
#                 "3": {
#                     "bottom": 0.6680689655172415,
#                     "left": 0.07584873949579832,
#                     "right": 0.9103411764705882,
#                     "top": 0.6378376932223543
#                 },
#                 "4": {
#                     "bottom": 0.7598799048751486,
#                     "left": 0.07584873949579832,
# ...
