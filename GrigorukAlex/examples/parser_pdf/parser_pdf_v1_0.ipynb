# %%
# !sudo apt update
# !sudo apt install xpdf
# !pip install pdfplumber
# !pip install pdf2image
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,016 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,242 kB]
# Get:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !git clone https://github.com/grigorukalex/parser_pdf.git
# Out:
# Cloning into 'parser_pdf'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 84 (delta 6), reused 38 (delta 4), pack-reused 42
# Receiving objects: 100% (84/84), 51.44 MiB | 42.24 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
from parser_pdf.parser_pdf.bboxes import parse

pdf_path = '/content/parser_pdf/examples/parser_pdf/db/testPDF.pdf'
parse(pdf_path,
      skip_num_tables=4,    # Кол-во таблиц, которые нужно пропустить на первой странице
      padding=(1.0, 0.95)   # Отступ сверху и сниху от границ таблицы в % от ширины и высоты страницы
      )
# Out:
# (595, 841)
# Кол-во страниц в PDF:  3  | Файл:  /content/parser_pdf/examples/parser_pdf/db/testPDF.pdf
# Кол-во таблиц на странице  1  :  5  шт
# Кол-во таблиц на странице  2  :  10  шт
# Кол-во таблиц на странице  3  :  0  шт
# ...

# %%
from google.colab.patches import cv2_imshow
from PIL import Image

path_img = '/content/parser_pdf/examples/parser_pdf/db/testPDF/'

img = Image.open(path_img + 'page_1.png')
display(img)
img = Image.open(path_img + 'page_2.png')
display(img)
img = Image.open(path_img + 'page_3.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1654x2339>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1654x2339>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1654x2339>

# %%
import json
with open('/content/parser_pdf/examples/parser_pdf/db/testPDF.json', 'r') as f:
  json_string = json.dumps(json.load(f), default=lambda o: o.__dict__, sort_keys=True, indent=4)
print(json_string)
# Out:
# {
#     "num_pages": 3,
#     "pages": {
#         "1": {
#             "num_tables": 5,
#             "tables": {
#                 "1": {
#                     "x1": 0.07484873949579832,
#                     "x2": 0.9093411764705882,
#                     "y1": 0.5239244946492272,
#                     "y2": 0.5606557669441141
#                 },
#                 "2": {
#                     "x1": 0.07484873949579832,
#                     "x2": 0.9093411764705882,
#                     "y1": 0.5866521997621879,
#                     "y2": 0.6233834720570748
#                 },
#                 "3": {
#                     "x1": 0.07484873949579832,
#                     "x2": 0.9093411764705882,
#                     "y1": 0.6348376932223543,
#                     "y2": 0.6715689655172414
#                 },
#                 "4": {
#                     "x1": 0.07484873949579832,
#                     "x2": 0.9093411764705882,
# ...
